# %% [markdown]
# # LAB-04
# ### ------------------------------------------------------
# ### DATE - 30th/August/2024
# ### ------------------------------------------------------

# %% [markdown]
# #### Annualsales.csv

# %%
pwd
# Out:
# 'C:\\Users\\android\\OneDrive - Amrita Vishwa Vidyapeetham\\Machine_Learning_Lab'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('Annualsales.csv')

# %%
df
# Out:
#     District  annual net sales  number of stores in district
# 0          1               231                            12
# 1          2               156                            13
# 2          3                10                            16
# 3          4               519                             2
# 4          5               437                             6
# 5          6               309                            11
# 6          7               234                            12
# 7          8                88                            13
# 8          9               597                             2
# 9         10               515                            16
# 10        11               215                            18
# 11        12               140                            11
# 12        13               143                             7
# 13        14               503                             8
# ...

# %%
df.isnull().sum()
# Out:
# District                        0
# annual net sales                0
# number of stores in district    0
# dtype: int64

# %%
sales = df.rename(columns={'annual net sales':'sales','number of stores in district':'stores'})
sales.head()
# Out:
#    District  sales  stores
# 0         1    231      12
# 1         2    156      13
# 2         3     10      16
# 3         4    519       2
# 4         5    437       6

# %% [markdown]
# ### PLOT

# %%
y=sales['sales']
x=sales.stores

# %%
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.plot(x,y,'o',markersize=15)
plt.ylabel('Annual Net Sales', fontsize=30)
plt.xlabel('Number of Stores in the District', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# ### Calculate Slope and y-intercept of the Linear Regression

# %%
m, b =np.polyfit(x,y,1)
print('The slope of line is {:.2f}.'.format(m))
print('The y-intercept is {:.2f}.'.format(b))
print('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b))
# Out:
# The slope of line is -9.55.
# The y-intercept is 423.52.
# The best fit simple linear regression line is -9.55x + 423.52.

# %% [markdown]
# ### Calculate the Centroid

# %%
y_mean = y.mean()
x_mean = x.mean()
print('The centroid for this dataset is x={:.2f} and y={:.2f}.'.format(x_mean,y_mean))
# Out:
# The centroid for this dataset is x=10.81 and y=320.27.

# %% [markdown]
# ### Overlay the Regression Line and the Centroid point on the plot

# %%
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.plot(x,y, 'o',markersize=14, label="Annual Net Sales")
plt.plot(x_mean,y_mean,'*', markersize=30, color ='r')
plt.plot(x,m*x+b,'-', label='Simple Linear Regression Line',linewidth=4)
plt.ylabel('Annual Net Sales', fontsize=30)
plt.xlabel('Number of Stores in District', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.annotate('Centroid',xy=(x_mean-0.1,y_mean-5),xytext=(x_mean-3,y_mean-20),arrowprops=dict(facecolor='black',shrink=0.05),fontsize=30)
plt.legend(loc='upper right', fontsize=20)

# %% [markdown]
# ### Prediction

# %%
def predict(query):
    if query >=1:
        predict = m*query+b
        return predict
    else:
        print("You must have at least 1 store in the districet to predict the annual net sales.")

# %%
predict(4)
# Out:
# 385.31618822548126

# %%
predict(13)
# Out:
# 299.3626537846666

# %% [markdown]
# ## Stores.csv

# %%
df1=pd.read_csv('Stores.csv')

# %%
df1
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Store ID \tStore_Area\tItems_Available\tDaily_Customer_Count\tStore_Sales    0
# dtype: int64

# %%
sales1 = df1.rename(columns={'Daily_Customer_Count':'customer','Store_Sales':'sales'})
sales1.head()
# Out:
#    Store ID   Store_Area  Items_Available  customer  sales
# 0          1        1659             1961       530  66490
# 1          2        1461             1752       210  39820
# 2          3        1340             1609       720  54010
# 3          4        1451             1748       620  53730
# 4          5        1770             2111       450  46620

# %%
y1=sales1['sales']
x1=sales1.Items_Available

# %%
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.plot(x1,y1,'o',markersize=15)
plt.ylabel('Sales', fontsize=30)
plt.xlabel('Items_Available', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
m, b =np.polyfit(x1,y1,1)
print('The slope of line is {:.2f}.'.format(m))
print('The y-intercept is {:.2f}.'.format(b))
print('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b))
# Out:
# The slope of line is 5.67.
# The y-intercept is 49252.98.
# The best fit simple linear regression line is 5.67x + 49252.98.

# %%
y1_mean = y1.mean()
x1_mean = x1.mean()
print('The centroid for this dataset is x={:.2f} and y={:.2f}.'.format(x1_mean,y1_mean))
# Out:
# The centroid for this dataset is x=1782.04 and y=59351.31.

# %%
# %matplotlib inline
plt.figure(figsize=(20,10))
plt.plot(x1,y1, 'o',markersize=14, label="Sales")
plt.plot(x1_mean,y1_mean,'*', markersize=30, color ='r')
plt.plot(x1,m*x1+b,'-', label='Simple Linear Regression Line',linewidth=4)
plt.ylabel('Sales', fontsize=30)
plt.xlabel('Items_Available', fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.annotate('Centroid',xy=(x1_mean-0.1,y1_mean-5),xytext=(x1_mean-3,y1_mean-20),arrowprops=dict(facecolor='black',shrink=0.05),fontsize=30)
plt.legend(loc='upper right', fontsize=20)

# %%
def predict2(query):
    if query >=1:
        predict2 = m*query+b
        return predict2
    else:
        print("You must have at least 1 store in the districet to predict the annual net sales.")

# %%
predict2(0)
# Out:
# You must have at least 1 store in the districet to predict the annual net sales.

# %% [markdown]
# ## Correlation

# %%
import seaborn as sns
sns.heatmap(sales1.iloc[:,1:5].corr(),annot=True,cmap="coolwarm")
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# ## Visualization

# %%
sns.pairplot(data=sales1.iloc[:,1:5])

# %%
sns.scatterplot(x=sales1.Store_Area, y=sales1.sales, hue=sales1.Items_Available)
# Out:
# <AxesSubplot:xlabel='Store_Area', ylabel='sales'>

# %%
sales['']
